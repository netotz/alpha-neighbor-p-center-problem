# %% [markdown]
# # Understanding the objective function of the $\alpha$-neighbor _p_-center problem

# %% [markdown]
# The objective function of the problem is defined as:
#
# $$
# \mathcal{F}^\alpha (P) = \max\limits_{v \in V \setminus P}
#         \min\limits_{S \subseteq P, |S| = \alpha}
#             \max\limits_{s \in S}{d(s, v)}
# $$
#
# Where $V$ is the set of initial vertices, $P$ is the solution set, and $d(i,j)$ is the function of distance or dissimilarity from node $i$ to $j$.

# %% [markdown]
# The parameters for this demonstration will be:
# * $n = 8$
# * $p = 3$
# * $\alpha = 2$

# %%
n = 8
p = 3
alpha = 2

# %% [markdown]
# Let's generate random points:

# %%
import obj_func_module as ofm

vertices = ofm.generate_randoms(n, 100, 100)
vertices
# Out:
# [(71, 14), (96, 80), (53, 34), (70, 92), (9, 38), (84, 61), (34, 52), (3, 91)]

# %%
import matplotlib.pyplot as plt

ofm.config_plot_points(vertices, 'gray')
plt.show()

# %% [markdown]
# And select a random solution, which is also feasible:

# %%
import random

solution = random.sample(vertices, p)
solution
# Out:
# [(84, 61), (70, 92), (53, 34)]

# %%
clients = set(vertices) - set(solution)
ofm.config_plot_points(clients, 'skyblue')
ofm.config_plot_points(solution, 'red')
plt.show()

# %% [markdown]
# Clients are plotted in blue and facilities in red.
#
# At each iteration, the current client is marked as a star, and the current solution subset of size $\alpha$ is marked as crosses. For each client, the distance to its $\alpha$-th closest facility is the orange line, i.e. its assigned facility.
#
# The green line is the maximum distance of any client to its assigned facility, i.e. the objective function:

# %%
ofm.eval_obj_func(alpha, clients, solution)
# Out:
# New maximum for subset d(s, c): 50.80354318352215
# New maximum for subset d(s, c): 53.81449618829485
# New minimum, client allocated: 53.81449618829485
# New maximum for subset d(s, c): 50.80354318352215
# New minimum, client allocated: 50.80354318352215
# New maximum for subset d(s, c): 53.81449618829485
# New objective function value: 50.80354318352215
# New maximum for subset d(s, c): 78.44743462982075
# New maximum for subset d(s, c): 81.46778504415104
# New minimum, client allocated: 81.46778504415104
# New maximum for subset d(s, c): 78.44743462982075
# New minimum, client allocated: 78.44743462982075
# New maximum for subset d(s, c): 81.46778504415104
# New objective function value: 78.44743462982075
# New maximum for subset d(s, c): 86.37708029332781
# New minimum, client allocated: 86.37708029332781
# New maximum for subset d(s, c): 86.37708029332781
# New maximum for subset d(s, c): 67.00746227100382
# New maximum for subset d(s, c): 75.82216034906945
# New minimum, client allocated: 75.82216034906945
# New maximum for subset d(s, c): 22.47220505424423
# New maximum for subset d(s, c): 28.635642126552703
# New minimum, client allocated: 28.635642126552703
# New maximum for subset d(s, c): 22.47220505424423
# New maximum for subset d(s, c): 62.96824596572467
# New maximum for subset d(s, c): 28.635642126552703
# New maximum for subset d(s, c): 62.96824596572467
# New maximum for subset d(s, c): 48.76474136094644
# New maximum for subset d(s, c): 78.00640999302557
# New minimum, client allocated: 78.00640999302557
# New maximum for subset d(s, c): 48.76474136094644
# New minimum, client allocated: 48.76474136094644
# New maximum for subset d(s, c): 78.00640999302557
# 78.44743462982075
