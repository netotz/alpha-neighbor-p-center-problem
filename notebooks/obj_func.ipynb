# %% [markdown]
# # Understanding the objective function of the $\alpha$-neighbor _p_-center problem

# %% [markdown]
# The objective function of the problem is defined as:
#
# $$
# \mathcal{F}^\alpha (P) = \max\limits_{v \in V \setminus P}
#         \min\limits_{S \subseteq P, |S| = \alpha}
#             \max\limits_{s \in S}{d(s, v)}
# $$
#
# Where $V$ is the set of initial vertices, $P$ is the solution set, and $d(i,j)$ is the function of distance or dissimilarity from node $i$ to $j$.

# %% [markdown]
# The parameters for this demonstration will be:
# * $n = 8$
# * $p = 3$
# * $\alpha = 2$

# %%
n = 8
p = 3
alpha = 2

# %% [markdown]
# Let's generate random points:

# %%
import obj_func_module as ofm

vertices = ofm.generate_randoms(n, 100, 100)
vertices
# Out:
# [(39, 89),
#  (18, 13),
#  (40, 63),
#  (100, 94),
#  (19, 96),
#  (92, 26),
#  (24, 29),
#  (57, 23)]

# %%
import matplotlib.pyplot as plt

ofm.config_plot_points(vertices, 'gray')
plt.show()

# %% [markdown]
# And select a random solution, which is also feasible:

# %%
from random import sample

solution = sample(vertices, p)
solution
# Out:
# [(100, 94), (18, 13), (39, 89)]

# %%
clients = set(vertices) - set(solution)
ofm.config_plot_points(clients, 'skyblue')
ofm.config_plot_points(solution, 'red')
plt.show()

# %% [markdown]
# Clients are plotted in blue and facilities in red.
#
# At each iteration, the current client is marked as a star, and the current solution subset of size $\alpha$ is marked as crosses. For each client, the distance to its $\alpha$-th closest facility is the orange line, i.e. its assigned facility.
#
# The green line is the maximum distance of any client to its assigned facility, i.e. the objective function:

# %%
ofm.eval_obj_func(alpha, clients, solution)
# Out:
# New maximum for subset d(s, c): 68.46897107449476
# New maximum for subset d(s, c): 75.13321502504735
# New minimum, client allocated: 75.13321502504735
# New maximum for subset d(s, c): 68.46897107449476
# New maximum for subset d(s, c): 82.32860985101108
# New maximum for subset d(s, c): 75.13321502504735
# New maximum for subset d(s, c): 82.32860985101108
# New objective function value: 75.13321502504735
# New maximum for subset d(s, c): 83.00602387778854
# New minimum, client allocated: 83.00602387778854
# New maximum for subset d(s, c): 83.00602387778854
# New maximum for subset d(s, c): 40.2616442783948
# New maximum for subset d(s, c): 68.41052550594827
# New minimum, client allocated: 68.41052550594827
# New maximum for subset d(s, c): 100.00499987500625
# New minimum, client allocated: 100.00499987500625
# New maximum for subset d(s, c): 100.00499987500625
# New maximum for subset d(s, c): 17.08800749063506
# New maximum for subset d(s, c): 61.84658438426491
# New minimum, client allocated: 61.84658438426491
# New maximum for subset d(s, c): 81.02468759581859
# New maximum for subset d(s, c): 83.00602387778855
# New minimum, client allocated: 83.00602387778855
# New maximum for subset d(s, c): 81.02468759581859
# New minimum, client allocated: 81.02468759581859
# New maximum for subset d(s, c): 83.00602387778855
# New objective function value: 81.02468759581859
# New maximum for subset d(s, c): 67.53517601961218
# New minimum, client allocated: 67.53517601961218
# New maximum for subset d(s, c): 67.53517601961218
# New maximum for subset d(s, c): 54.62600113499065
# New minimum, client allocated: 54.62600113499065
# 81.02468759581859
