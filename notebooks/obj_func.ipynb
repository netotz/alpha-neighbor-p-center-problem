# %% [markdown]
# # Understanding the objective function of the $\alpha$-neighbor _p_-center problem.

# %% [markdown]
# The objective function of the problem is defined as:
#
# $$
# \mathcal{F}^\alpha (P) = \max\limits_{v \in V \setminus P}
#         \min\limits_{S \subseteq P, |S| = \alpha}
#             \max\limits_{s \in S}{d(s, v)}
# $$
#
# Where $V$ is the set of initial vertices, $P$ is the set of allocated facilities, and $d(i,j)$ is the function of distance or dissimilarity from node $i$ to $j$.

# %% [markdown]
# Let's generate random clients:

# %%
import matplotlib.pyplot as plt

import obj_func_module as ofm

clients = ofm.generate_randoms(5, 100, 100)
clients
# Out:
# [(1, 26), (24, 67), (67, 8), (82, 9), (80, 57)]

# %% [markdown]
# And random facilities:

# %%
facilities = ofm.generate_randoms(3, 100, 100)
facilities
# Out:
# [(18, 80), (70, 96), (8, 39)]

# %% [markdown]
# Clients are plotted in blue and facilities in red:

# %%
ofm.config_plot_points(clients, 'skyblue')
ofm.config_plot_points(facilities, 'red')
plt.show()

# %%
ofm.eval_obj_func(2, clients, facilities)
# Out:
# Current client: (1, 26)
#
# Current subset: ((18, 80), (70, 96))
# Point from subset: (18, 80)
# New maximum d(s, c): 56.61271941887264
# Point from subset: (70, 96)
# New maximum d(s, c): 98.29038610159185
# New minimum d(c, S): 98.29038610159185
#
# Current subset: ((18, 80), (8, 39))
# Point from subset: (18, 80)
# New maximum d(s, c): 56.61271941887264
# Point from subset: (8, 39)
# New minimum d(c, S): 56.61271941887264
#
# Current subset: ((70, 96), (8, 39))
# Point from subset: (70, 96)
# New maximum d(s, c): 98.29038610159185
# Point from subset: (8, 39)
# New maximum distance: 56.61271941887264
#
# Current client: (24, 67)
#
# Current subset: ((18, 80), (70, 96))
# Point from subset: (18, 80)
# New maximum d(s, c): 14.317821063276352
# Point from subset: (70, 96)
# New maximum d(s, c): 54.378304497290095
# New minimum d(c, S): 54.378304497290095
#
# Current subset: ((18, 80), (8, 39))
# Point from subset: (18, 80)
# New maximum d(s, c): 14.317821063276352
# ...
